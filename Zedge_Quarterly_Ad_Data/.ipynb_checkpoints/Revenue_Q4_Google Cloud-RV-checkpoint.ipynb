# %%
#IMPORTS

# %%
import pandas as pd

from google.cloud import bigquery

from datetime import datetime
import datetime

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure

# %%
# Big Query Command to pull data
# %load_ext google.cloud.bigquery

# %%
# Pulling quarterly data from TY and LY Q4 (Oct thru Dec)

# %%bigquery rev_totals
SELECT date, app, business_type, clicks, platform, connection, ad_name, ad_format, impressions, ad_revenue, tier, country 
   FROM `wallpaperboard-6dd71.revenue.daily`
WHERE 
app = 'Zedge' AND 
platform = 'Android' AND
ad_revenue > 1.00 AND
((date >= '2017-10-01' AND date <= '2017-12-31') OR 
(date >= '2018-10-01' AND date <= '2018-12-31'))
;

### Worked up until 1.31 - no reason for the syntax error - query runs in big query
# Out:
#   File "<ipython-input-9-7eca80b3a96e>", line 4
#     SELECT date, app, business_type, clicks, platform, connection, ad_name, ad_format, impressions, ad_revenue, tier, country
#               ^
# SyntaxError: invalid syntax

# %%
#plan b to run Big query from JN

# %%
from google.cloud import bigquery
client = bigquery.Client()

# %%
sql = """
SELECT date, app, business_type, clicks, platform, connection, ad_name, ad_format, impressions, ad_revenue, tier, country 
   FROM `wallpaperboard-6dd71.revenue.daily`
WHERE 
app = 'Zedge' AND 
platform = 'Android' AND
ad_revenue > 1.00 AND
((date >= '2017-10-01' AND date <= '2017-12-31') OR 
(date >= '2018-10-01' AND date <= '2018-12-31'))

"""
rev_totals = client.query(sql).to_dataframe()
rev_totals.head()
# Out:
#          date    app business_type  clicks platform  connection ad_name  \
# 0  2018-10-04  Zedge           UGC       2  Android       Admob    MREC
# 1  2018-10-04  Zedge           UGC     138  Android      Adview  Banner
# 2  2018-10-04  Zedge           UGC      45  Android      Adview  Banner
# 3  2018-10-04  Zedge           UGC      87  Android      Adview  Banner
# 4  2018-10-04  Zedge           UGC     158  Android  Conversant  Banner
#
#   ad_format  impressions  ad_revenue  tier country
# 0   300x250          167        1.69     1      GB
# 1    320x50        45153        4.86     3      IN
# 2    320x50        10451        1.36     3      ID
# 3    320x50        33778       34.23     1      US
# 4    320x50        43032      149.58     1      US

# %%
# Keeping relevant fields
q4_revenue_data = rev_totals[['date','app','connection','clicks','ad_name','impressions','ad_revenue','tier','country']]

# %%
# GET MONTH AND YEAR
q4_revenue_data.date = pd.to_datetime(q4_revenue_data.date)

#q4_revenue_data.info()
q4_revenue_data['year'] = q4_revenue_data.date.dt.year
q4_revenue_data['month'] = q4_revenue_data.date.dt.month

#Ensure the Tier is a String
q4_revenue_data.tier = q4_revenue_data.tier.astype(str)

#Define a Higher Level Partner Field while Connection is manipulated
q4_revenue_data['partner'] = q4_revenue_data['connection']

q4_revenue_data.head()
# Out:
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         date    app  connection  clicks ad_name  impressions  ad_revenue tier  \
# 0 2018-10-04  Zedge       Admob       2    MREC          167        1.69    1
# 1 2018-10-04  Zedge      Adview     138  Banner        45153        4.86    3
# 2 2018-10-04  Zedge      Adview      45  Banner        10451        1.36    3
# 3 2018-10-04  Zedge      Adview      87  Banner        33778       34.23    1
# 4 2018-10-04  Zedge  Conversant     158  Banner        43032      149.58    1
#
#   country  year  month     partner
# 0      GB  2018     10       Admob
# 1      IN  2018     10      Adview
# 2      ID  2018     10      Adview
# 3      US  2018     10      Adview
# 4      US  2018     10  Conversant

# %%
#q4_revenue_data.reset_index(inplace=True)
#q4_revenue_data
q4_revenue_data.head()
#q4_revenue_data.set_index('connection', inplace=True)
q4_revenue_data.head()

q4_revenue_data.connection.value_counts()
# Out:
# Admob           75624
# Marketplace     45980
# Facebook        31509
# inMobi           8142
# Ogury            2456
# Nexage           1741
# Mobfox           1159
# unity3d.com       775
# OpenX             553
# Smaato            503
# Tap Research      464
# Rubicon           415
# Amazon TAM        392
# Baidu             373
# Adview            232
# Conversant        232
# Liftoff            47
# Millenial          38
# Pollfish           33
# Name: connection, dtype: int64

# %%
# for Analyses, various partners chose not to participate, they have been placed in the OTHER category
q4_revenue_data.set_index('connection', inplace=True)

q4_revenue_data.drop('Tap Research', inplace=True)
q4_revenue_data.drop('Pollfish', inplace=True)

# %%
# changing index cols with rename() 
q4_revenue_data.rename(index = {"Liftoff": "Other", 
                    "Rubicon": "Other",
                    "Smaato" : "Other",
                    "OpenX"  : 'Other',
                    "Millenial" :'Other',
                    "Nexage"  : 'Other',
                    "Baidu"   : 'Other',
                    "Adview"  : 'Other',
                    "unity3d.com" : 'Other',
                    "Conversant"  : 'Other',
                    "Mobfox"    : 'Other',
                    "Amazon TAM" : 'Other'},
          
                                  inplace = True) 

q4_revenue_data.head(10)
# Out:
#                  date    app  clicks ad_name  impressions  ad_revenue tier  \
# connection
# Admob      2018-10-04  Zedge       2    MREC          167        1.69    1
# Other      2018-10-04  Zedge     138  Banner        45153        4.86    3
# Other      2018-10-04  Zedge      45  Banner        10451        1.36    3
# Other      2018-10-04  Zedge      87  Banner        33778       34.23    1
# Other      2018-10-04  Zedge     158  Banner        43032      149.58    1
# inMobi     2018-10-04  Zedge     396  Banner        47020        1.79    3
# inMobi     2018-10-04  Zedge      89  Banner        25214       75.72    1
# inMobi     2018-10-04  Zedge      88  Banner        13209        2.02    2
# inMobi     2018-10-04  Zedge      27  Banner        17156        3.08    2
# inMobi     2018-10-04  Zedge     248  Banner        21218        5.57    3
#
#            country  year  month     partner
# connection
# Admob           GB  2018     10       Admob
# Other           IN  2018     10      Adview
# Other           ID  2018     10      Adview
# Other           US  2018     10      Adview
# Other           US  2018     10  Conversant
# inMobi          AR  2018     10      inMobi
# inMobi          AU  2018     10      inMobi
# inMobi          AT  2018     10      inMobi
# inMobi          BE  2018     10      inMobi
# inMobi          BR  2018     10      inMobi

# %%
q4_revenue_data.reset_index(inplace=True)

# %% [markdown]
# ### Aggregate Revenue, ecpm, and SOW Analyses

# %%
q4_agg = q4_revenue_data.groupby(['connection','year']).sum()
del q4_agg['month']
q4_agg
# Out:
#                      clicks  impressions  ad_revenue
# connection  year
# Admob       2017    4855736   1230969671   568056.98
#             2018    4603439   1299906456   711195.80
# Facebook    2017    4004823    609869230   224639.05
#             2018    1311840    268745275    99494.84
# Marketplace 2017   16567696   1043947080  1198104.85
#             2018   19923265   1000875956   669858.39
# Ogury       2017          0     34685646   416227.50
#             2018          0     21869359   262432.32
# Other       2017     558020    146218230   114565.07
#             2018  255101728    128276418   378283.48
# inMobi      2017    2074727    190711605   130143.17
#             2018    1305916    154770277   220346.58

# %%
q4_agg.reset_index(inplace=True)
q4_agg
# Out:
#      connection  year     clicks  impressions  ad_revenue
# 0         Admob  2017    4855736   1230969671   568056.98
# 1         Admob  2018    4603439   1299906456   711195.80
# 2      Facebook  2017    4004823    609869230   224639.05
# 3      Facebook  2018    1311840    268745275    99494.84
# 4   Marketplace  2017   16567696   1043947080  1198104.85
# 5   Marketplace  2018   19923265   1000875956   669858.39
# 6         Ogury  2017          0     34685646   416227.50
# 7         Ogury  2018          0     21869359   262432.32
# 8         Other  2017     558020    146218230   114565.07
# 9         Other  2018  255101728    128276418   378283.48
# 10       inMobi  2017    2074727    190711605   130143.17
# 11       inMobi  2018    1305916    154770277   220346.58

# %%
q4_agg.sort_values('ad_revenue', ascending=False, inplace=True )

# %%
# Separate the 2017 and 2018 to calculate SOW
q42017 = q4_agg[q4_agg['year'] == 2017]
q42018 = q4_agg[q4_agg['year'] == 2018]

imp2017 = q42017['impressions'].sum()
imp2018 = q42018['impressions'].sum()
rev2017 = q42017['ad_revenue'].sum()
rev2018 = q42018['ad_revenue'].sum()

q42017['sow_imp'] = q42017.impressions / imp2017
q42017['sow_rev'] = q42017.ad_revenue /  rev2017

q42018['sow_imp'] = q42018.impressions / imp2018
q42018['sow_rev'] = q42018.ad_revenue /  rev2018

q42018
# Out:
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      connection  year     clicks  impressions  ad_revenue   sow_imp   sow_rev
# 1         Admob  2018    4603439   1299906456   711195.80  0.452229  0.303721
# 5   Marketplace  2018   19923265   1000875956   669858.39  0.348198  0.286067
# 9         Other  2018  255101728    128276418   378283.48  0.044627  0.161548
# 7         Ogury  2018          0     21869359   262432.32  0.007608  0.112073
# 11       inMobi  2018    1305916    154770277   220346.58  0.053844  0.094100
# 3      Facebook  2018    1311840    268745275    99494.84  0.093495  0.042490

# %%
# Combine the 2017 and 2018 files again for Graphing

frame = [q42018,q42017]
agg = pd.concat(frame)
agg
# Out:
#      connection  year     clicks  impressions  ad_revenue   sow_imp   sow_rev
# 1         Admob  2018    4603439   1299906456   711195.80  0.452229  0.303721
# 5   Marketplace  2018   19923265   1000875956   669858.39  0.348198  0.286067
# 9         Other  2018  255101728    128276418   378283.48  0.044627  0.161548
# 7         Ogury  2018          0     21869359   262432.32  0.007608  0.112073
# 11       inMobi  2018    1305916    154770277   220346.58  0.053844  0.094100
# 3      Facebook  2018    1311840    268745275    99494.84  0.093495  0.042490
# 4   Marketplace  2017   16567696   1043947080  1198104.85  0.320583  0.451819
# 0         Admob  2017    4855736   1230969671   568056.98  0.378015  0.214221
# 6         Ogury  2017          0     34685646   416227.50  0.010652  0.156964
# 2      Facebook  2017    4004823    609869230   224639.05  0.187283  0.084714
# 10       inMobi  2017    2074727    190711605   130143.17  0.058565  0.049078
# 8         Other  2017     558020    146218230   114565.07  0.044902  0.043204

# %% [markdown]
# ### GRAPHING SOW TY over LY CHART

# %%
from matplotlib.ticker import FuncFormatter

# fig = matplotlib.pyplot.gcf()
# fig.set_size_inches(18.5, 10.5)
# fig.savefig('test2png.png', dpi=100)

sns.set(rc={'figure.figsize':(10,10)})
sns.set_style("white")

sns.set(rc={"font.size":14,"axes.labelsize":14})
# Rotate the labels on x-axis

sns.set_style('white')
sns.set_palette(sns.color_palette("Paired"))


ax = sns.barplot(x ='connection', y='sow_rev', hue='year', data=agg)


plt.title("Q4 2018 vs Q4 2017 \n Partner Share of Wallet \n", fontsize=20)
plt.xlabel('\n Partner')
plt.ylabel('Share of Wallet \n' )
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y))) 
ax.grid(linestyle='-', linewidth='0.2', color='gray')

# We change the fontsize of minor ticks label 
plt.tick_params(axis='both', which='major', labelsize=14)
plt.tick_params(axis='both', which='minor', labelsize=14)

# 5. Place legend to the right
#plt.legend(bbox_to_anchor=(1, 1), loc=2, fontsize=20)
plt.legend(loc='upper right', fontsize=25)
plt.savefig('Q4_2018_2017_SOW-1', dpi=100)



# plt.figure(figsize=(15,8))
# ax = sns.barplot(x="Word", y="Frequency", data=boxdata)

# %%
merge = pd.merge(q42017,q42018, how='outer', on='connection')

merge
# Out:
#     connection  year_x    clicks_x  impressions_x  ad_revenue_x  sow_imp_x  \
# 0  Marketplace  2017.0  16567696.0   1.043947e+09    1198104.85   0.320583
# 1        Admob  2017.0   4855736.0   1.230970e+09     568056.98   0.378015
# 2        Ogury  2017.0         0.0   3.468565e+07     416227.50   0.010652
# 3     Facebook  2017.0   4004823.0   6.098692e+08     224639.05   0.187283
# 4       inMobi  2017.0   2074727.0   1.907116e+08     130143.17   0.058565
# 5        Other  2017.0    558020.0   1.462182e+08     114565.07   0.044902
# 6   Amazon TAM     NaN         NaN            NaN           NaN        NaN
#
#    sow_rev_x  year_y   clicks_y  impressions_y  ad_revenue_y  sow_imp_y  \
# 0   0.451819    2018   19923265     1000875956     669858.39   0.348198
# 1   0.214221    2018    4603439     1299906456     711195.80   0.452229
# 2   0.156964    2018          0       21869359     262432.32   0.007608
# 3   0.084714    2018    1311840      268745275      99494.84   0.093495
# 4   0.049078    2018    1305916      154770277     220346.58   0.053844
# 5   0.043204    2018  229066318      116921057     354258.84   0.040676
# 6        NaN    2018   26035410       11355361      24024.64   0.003950
#
#    sow_rev_y
# 0   0.286067
# 1   0.303721
# 2   0.112073
# 3   0.042490
# 4   0.094100
# 5   0.151288
# 6   0.010260

# %% [markdown]
# ### Looking at Percent Change from TY vs LY (Didn't like the graphical repesentation)

# %%
merge['perc_change'] = (merge.ad_revenue_y - merge.ad_revenue_x) / merge.ad_revenue_x
merge['ecpm_y'] = merge.ad_revenue_y / merge.impressions_y * 1000
merge

table = merge[['connection','sow_imp_y','sow_rev_y','perc_change','ecpm_y']]
table
# Out:
#     connection  sow_imp_y  sow_rev_y  perc_change     ecpm_y
# 0  Marketplace   0.348198   0.286067    -0.440902   0.669272
# 1        Admob   0.452229   0.303721     0.251980   0.547113
# 2        Ogury   0.007608   0.112073    -0.369498  12.000001
# 3     Facebook   0.093495   0.042490    -0.557090   0.370220
# 4       inMobi   0.053844   0.094100     0.693109   1.423701
# 5        Other   0.040676   0.151288     2.092206   3.029898
# 6   Amazon TAM   0.003950   0.010260          NaN   2.115709

# %% [markdown]
# ### Evaluating TY vs LY ecpms

# %%
# Look at Total impressions 2018 vs 2017 by Tier
q4_revenue_data.ad_name.value_counts()


# Get Totals by Year
total_yr = q4_revenue_data.groupby('year').sum()
total_yr['ecpm'] = total_yr['ad_revenue'] / total_yr['impressions'] * 1000

total_yr
# Out:
#          clicks  impressions  ad_revenue   month      ecpm
# year
# 2017   28061002   3256401462  2651736.62  959505  0.814315
# 2018  282246188   2874443741  2341611.41  916377  0.814631

# %% [markdown]
# ### Evluating TY vs LY ecpms by Tier and Percent of Revenue of Each Tier

# %%
#totals = q4_revenue_data.groupby(['tier'])
totals = q4_revenue_data.groupby(['year','tier']).sum()

totals.reset_index(inplace=True)
total2017 = totals[totals['year'] == 2017]
total2018 = totals[totals['year'] == 2018]

#total2017.reset_index(inplace=True)
rev_2017 = total2017['ad_revenue'].sum()
rev_2018 = total2018['ad_revenue'].sum()

total2017['ecpm'] = total2017.ad_revenue /total2017.impressions * 1000
total2017['per_rev'] = total2017.ad_revenue / rev_2017
total2018['ecpm'] = total2018.ad_revenue /total2018.impressions * 1000
total2018['per_rev'] = total2018.ad_revenue / rev_2018

total2017
# Out:
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#    year tier    clicks  impressions  ad_revenue   month      ecpm   per_rev
# 0  2017    1  10877180   1160616122  1847374.83  122419  1.591719  0.696666
# 1  2017    2   3026942    398533074   341685.21  242044  0.857357  0.128853
# 2  2017    3  14156880   1697252266   462676.58  595042  0.272603  0.174481

# %% [markdown]
# ### Defining the Tiers for Labels for Graphing

# %%
frame1 = [total2018,total2017]
agg_total = pd.concat(frame1)
agg_total

agg_total.loc[agg_total.tier == '1', 'country'] = 'US & UK,CA,AU'
agg_total.loc[agg_total.tier == '2', 'country'] = 'Europe'
agg_total.loc[agg_total.tier == '3', 'country'] = 'Rest of World'

agg_total.loc[agg_total.year == 2018, 'quarter'] = 'Q4 2018'
agg_total.loc[agg_total.year == 2017, 'quarter'] = 'Q4 2017'



agg_total
# Out:
#    year tier     clicks  impressions  ad_revenue   month      ecpm   per_rev  \
# 3  2018    1  142610727    762757875  1520743.80  127709  1.993744  0.649443
# 4  2018    2    2456639    319986427   271782.85  212754  0.849357  0.116067
# 5  2018    3  137178822   1791699439   549084.76  575914  0.306460  0.234490
# 0  2017    1   10877180   1160616122  1847374.83  122419  1.591719  0.696666
# 1  2017    2    3026942    398533074   341685.21  242044  0.857357  0.128853
# 2  2017    3   14156880   1697252266   462676.58  595042  0.272603  0.174481
#
#          country  quarter
# 3  US & UK,CA,AU  Q4 2018
# 4         Europe  Q4 2018
# 5  Rest of World  Q4 2018
# 0  US & UK,CA,AU  Q4 2017
# 1         Europe  Q4 2017
# 2  Rest of World  Q4 2017

# %% [markdown]
# ## Want to include the AVG across ALL Countries in the Tier Level ecpm Graph

# %%
average18 = agg_total[(agg_total['year'] == 2018 ) & (agg_total['tier'] == '1')]
average17 = agg_total[(agg_total['year'] == 2017 ) & (agg_total['tier'] == '1')]

#grab global avg 2017 and 2018 ecpms here - I chose to do it manually for simplicity
#total_year.reset_index(inplace=True)

average18['tier'] = '4'
average17['tier'] = '4'
average18['ecpm'] = .81
average17['ecpm'] = .81
average17['country'] = 'All Countries'
average18['country'] = 'All Countries'

frames = [average18,average17,agg_total]

ecpms = pd.concat(frames)
# Out:
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %% [markdown]
# ### eCPMs by Country Tier

# %%
# ecpms by Tier Graph 

from matplotlib.ticker import FuncFormatter

# fig = matplotlib.pyplot.gcf()
# fig.set_size_inches(18.5, 10.5)
# fig.savefig('test2png.png', dpi=100)

sns.set(rc={'figure.figsize':(10,10)})
sns.set_style("white")

sns.set(rc={"font.size":14,"axes.labelsize":14})
# Rotate the labels on x-axis

sns.set_style('white')
sns.set_palette(sns.color_palette("Blues"))

ax = sns.barplot(x ='country', y='ecpm', hue='quarter', data=ecpms)


plt.title("Q4 2018 vs Q4 2017 \n eCPM by Country Tier \n", fontsize=20)
plt.xlabel('\n Country Tier', fontsize=15)
plt.ylabel('eCPM \n', fontsize=15 )
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '${:.2}'.format(y))) 
ax.grid(linestyle='-', linewidth='0.2', color='gray')

# We change the fontsize of minor ticks label 
plt.tick_params(axis='both', which='major', labelsize=16)
plt.tick_params(axis='both', which='minor', labelsize=16)

# 5. Place legend to the right
#plt.legend(bbox_to_anchor=(1, 1), loc=2, fontsize=20)
plt.legend(loc='upper right', fontsize=25)
plt.savefig('Q4_2018_2017_eCPM', dpi=100)

# %% [markdown]
# ## Percent of Revenue by Country Tier

# %%
from matplotlib.ticker import FuncFormatter

# fig = matplotlib.pyplot.gcf()
# fig.set_size_inches(18.5, 10.5)
# fig.savefig('test2png.png', dpi=100)

sns.set(rc={'figure.figsize':(10,10)})
sns.set_style("white")

sns.set(rc={"font.size":14,"axes.labelsize":14})
# Rotate the labels on x-axis

sns.set_style('white')
sns.set_palette(sns.color_palette("Greens"))



ax = sns.barplot(x ='country', y='per_rev', hue='quarter', data=agg_total)


plt.title("Q4 2018 vs Q4 2017 \n Percent of Revenue by Country Tier \n", fontsize=20)
plt.xlabel('\n Country Tier')
plt.ylabel('Percent of Revenue \n' )
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y))) 
ax.grid(linestyle='-', linewidth='0.2', color='gray')

# We change the fontsize of minor ticks label 
plt.tick_params(axis='both', which='major', labelsize=16)
plt.tick_params(axis='both', which='minor', labelsize=16)

# 5. Place legend to the right
#plt.legend(bbox_to_anchor=(1, 1), loc=2, fontsize=20)
plt.legend(loc='upper right', fontsize=25)
plt.savefig('Q4_2018_2017_P_REV', dpi=100)

# %%
df_country = q4_revenue_data[q4_revenue_data['year'] == 2018]

df_country1 = df_country.groupby('country').sum()
df_country1.reset_index(inplace=True)

# %%
codes = pd.read_csv('countries.csv')
codes['country'].nunique()
#df_country1['country'].nunique()
# Out:
# 221

# %%
df_merge = pd.merge(df_country1,codes, on='country', how='inner')

# %%
### Ad Format by Country Tier - eCPMs and percent of Total Revenue

# %%
# Look at 2018 Data - Want to remove FS ads and RV for now, focusing on native and banner/mrecs only
q4_2018 = q4_revenue_data[q4_revenue_data['year'] == 2018]
q4_2018s = q4_2018.groupby(['tier', 'ad_name']).sum()

# ecpm by tier and ad name
q4_2018s['ecpm'] = q4_2018s.ad_revenue / q4_2018s.impressions * 1000
q4_2018s

q4_2018s.reset_index(inplace=True)
q4_2018s.set_index('ad_name', inplace=True)
#remove Native Banner - data cleansing error and was a test ad- small $$$ not relevant
q4_2018s.drop('Native Banner', inplace=True)
q4_2018s.reset_index(inplace=True)
q4_2018s

# FS and RV for 2018 by tier and Ad_name - REVISIT LATER
#q4_2018int = q4_2018s[(q4_2018s['ad_name'] == 'Interstitial') | (q4_2018s['ad_name'] == 'Rewarded Video')]

q4_2018ban = q4_2018s[q4_2018s['ad_name'] != 'Interstitial']
q4_2018ban = q4_2018ban[q4_2018ban['ad_name'] != 'Rewarded Video']

q4_2018ban

q4_2018ban.loc[q4_2018ban.tier == '1', 'country'] = 'US & UK,CA,AU'
q4_2018ban.loc[q4_2018ban.tier == '2', 'country'] = 'Europe'
q4_2018ban.loc[q4_2018ban.tier == '3', 'country'] = 'Rest of World'

q4_2018ban
# Out:
#           ad_name tier     clicks  impressions  ad_revenue      year   month  \
# 0          Banner    1  119502433    399597424   409792.85   4502158   24797
# 2            MREC    1      21397      2682745     8299.89    617508    3574
# 3   Native Browse    1      67315     21155683    17323.17   1925172   10348
# 4     Native Item    1    2232219    198786825   473923.26   3016910   16441
# 5   Native Search    1     264899     31859614    30626.65   2500302   13575
# 6    Native Swipe    1     306911     50025166    50166.43   2790894   15191
# 8          Banner    2     846097    160025308    71093.75   9204098   50253
# 10           MREC    2      11904      1694548     3176.89    849578    5009
# 11  Native Browse    2      38906     10150935     6268.84   2851434   15040
# 12    Native Item    2     599335     94436076    64822.16   7981190   43526
# 13  Native Search    2      55268      7281167     4251.85   2490212   13641
# 14   Native Swipe    2     106417     20931424     9739.76   4009766   21934
# 16         Banner    3   93754180    793080533   126630.57  25243162  138505
# 18           MREC    3     142471     10809099     4640.52   2393348   14206
# 19  Native Browse    3     185362     69442547    11654.73   6782498   36124
# 20    Native Item    3    3924051    588833945   135905.02  22759004  124314
# 21  Native Search    3     315700     37246379     8663.71   5384024   29478
# 22   Native Swipe    3     592017    129361807    20834.26   9999190   55071
#
#         ecpm        country
# 0   1.025514  US & UK,CA,AU
# 2   3.093805  US & UK,CA,AU
# 3   0.818842  US & UK,CA,AU
# 4   2.384078  US & UK,CA,AU
# 5   0.961300  US & UK,CA,AU
# 6   1.002824  US & UK,CA,AU
# 8   0.444266         Europe
# 10  1.874771         Europe
# 11  0.617563         Europe
# 12  0.686413         Europe
# 13  0.583952         Europe
# 14  0.465318         Europe
# 16  0.159669  Rest of World
# 18  0.429316  Rest of World
# 19  0.167833  Rest of World
# 20  0.230804  Rest of World
# 21  0.232605  Rest of World
# 22  0.161054  Rest of World

# %% [markdown]
# ### Chart for the ecpms by Ad Type

# %%
from matplotlib.ticker import FuncFormatter

# fig = matplotlib.pyplot.gcf()
# fig.set_size_inches(18.5, 10.5)
# fig.savefig('test2png.png', dpi=100)

sns.set(rc={'figure.figsize':(10,10)})
sns.set_style("white")

sns.set(rc={"font.size":12,"axes.labelsize":12})
# Rotate the labels on x-axis

sns.set_style('white')
sns.set_palette(sns.color_palette("Paired"))


ax = sns.barplot(x ='ad_name', y='ecpm', hue='country',data=q4_2018ban)


plt.title("eCPMs by Zedge Ad \n", fontsize=20)
plt.xlabel('\n Zedge Ad')
plt.ylabel('eCPM \n' )
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '${:.2f}'.format(y))) 
ax.grid(linestyle='-', linewidth='0.2', color='gray')

# We change the fontsize of minor ticks label 
plt.tick_params(axis='both', which='major', labelsize=13)
plt.tick_params(axis='both', which='minor', labelsize=13)

# 5. Place legend to the right
#plt.legend(bbox_to_anchor=(1, 1), loc=2, fontsize=20)
plt.legend(loc='upper right', fontsize=15)
plt.savefig('Q4_2018_2017_Ad_eCPM', dpi=100)



# plt.figure(figsize=(15,8))
# ax = sns.barplot(x="Word", y="Frequency", data=boxdata)

# %% [markdown]
# ## Look at eCPM by Ad Type by CTR

# %%
q4_2018t1 = q4_2018ban[q4_2018ban['tier'] == '1']

q4_2018t1['ctr'] = q4_2018t1['clicks'] / q4_2018t1.impressions
q4_2018t1.loc[q4_2018t1.ad_name == 'Banner', 'ctr'] = .0036
q4_2018t1['p_rev'] = q4_2018t1.ad_revenue / q4_2018t1.ad_revenue.sum()
#q4_2018t1['ecpm'] = q4_2018t1.ad_revenue / q4_2018t1.impressions * 100

q4_2018t1.set_index('ad_name',inplace=True)
q4_2018t1

new_index = ['MREC', 'Native Item', 'Banner', 'Native Swipe', 'Native Search', 'Native Browse']

q4_2018t1 = q4_2018t1.reindex(new_index)

q4_2018t1
q4_2018t1.reset_index(inplace=True)
# Out:
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /Users/deeannbelsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
from matplotlib.ticker import FuncFormatter

# fig = matplotlib.pyplot.gcf()
# fig.set_size_inches(18.5, 10.5)
# fig.savefig('test2png.png', dpi=100)

sns.set(rc={'figure.figsize':(10,10)})
sns.set_style("white")

sns.set(rc={"font.size":12,"axes.labelsize":12})
# Rotate the labels on x-axis

sns.set_style('white')
sns.set_palette(sns.color_palette("Paired"))

axes2 = ax.twinx()   # mirror them

ax = sns.barplot(x ='ad_name', y='ecpm',data=q4_2018t1)
#plt.plot(q4_2018t1['ad_name'],q4_2018t1['ctr'] , color='black')
axes2= q4_2018t1['ctr'].plot(secondary_y=True, color='black' )

#ax2 = table[1].plot(secondary_y=True,color=colors[1], ax=ax)
#ax.set_ylabel('Left axes label')
#axes2.ylabel('CTR %')


plt.title("US and UK,CA, AU (Tier 1) eCPMs \n by Zedge Ad \n and associated CTRs \n", fontsize=20)
ax.set_xlabel('\n Zedge Ad ')
ax.set_ylabel('eCPM \n' )
axes2.set_ylabel('\n CTR %')
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '${:.2f}'.format(y))) 
axes2.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.1%}'.format(y))) 
ax.grid(linestyle='-', linewidth='0.2', color='gray')

ax.text(.27,1.9,'.80% CTR',fontweight='bold',horizontalalignment='right')
ax.text(1.4,3.1,'1.12% CTR',fontweight='bold',horizontalalignment='right')
ax.text(2.3, .23,'.36% CTR',fontweight='bold',horizontalalignment='right')
ax.text(3.3, 1.2,'.61% CTR',fontweight='bold',horizontalalignment='right')
ax.text(4.3, 2.0,'.83% CTR',fontweight='bold',horizontalalignment='right')
ax.text(5.3, .1,'.32% CTR',fontweight='bold',horizontalalignment='right')



#plt.legend(loc='upper right', fontsize=15)
#plt.show()
plt.savefig('Q4_2018_2017_Ad_eCPMT1', dpi=100)

# %%
q4_2018t1
# Out:
#          ad_name tier     clicks  impressions  ad_revenue     year  month  \
# 0           MREC    1      21397      2682745     8299.89   617508   3574
# 1    Native Item    1    2232219    198786825   473923.26  3016910  16441
# 2         Banner    1  119502433    399597424   409792.85  4502158  24797
# 3   Native Swipe    1     306911     50025166    50166.43  2790894  15191
# 4  Native Search    1     264899     31859614    30626.65  2500302  13575
# 5  Native Browse    1      67315     21155683    17323.17  1925172  10348
#
#        ecpm        country       ctr     p_rev
# 0  3.093805  US & UK,CA,AU  0.007976  0.008383
# 1  2.384078  US & UK,CA,AU  0.011229  0.478646
# 2  1.025514  US & UK,CA,AU  0.003600  0.413877
# 3  1.002824  US & UK,CA,AU  0.006135  0.050666
# 4  0.961300  US & UK,CA,AU  0.008315  0.030932
# 5  0.818842  US & UK,CA,AU  0.003182  0.017496

# %% [markdown]
# ### SOW by Ad Type:  Banner, MREC, Native, FS, and Rewarded Video

# %%
#Standardize the Native ads to all Native for SOW analyses

# q4_revenue_data.head(10)
# q4_revenue_data.country.value_counts()
# q4_revenue_data.ad_name.value_counts()

q4_revenue_data.set_index('ad_name', inplace=True)
q4_revenue_data.rename(index = 
                   {"Native Item"   : "Native", 
                    "Native Swipe"  : "Native",
                    "Native Search" : "Native",
                    "Native Banner" : 'Native',
                    "Native Browse" : "Native"
                   
                    },
                    inplace = True) 

q4_revenue_data
# q4_agg.reset_index(inplace=True)
# q4_agg.ad_name.value_counts()
# Out:
#              connection       date    app  clicks  impressions  ad_revenue  \
# ad_name
# MREC              Admob 2018-10-04  Zedge       2          167        1.69
# Banner            Other 2018-10-04  Zedge     138        45153        4.86
# Banner            Other 2018-10-04  Zedge      45        10451        1.36
# Banner            Other 2018-10-04  Zedge      87        33778       34.23
# Banner            Other 2018-10-04  Zedge     158        43032      149.58
# Banner           inMobi 2018-10-04  Zedge     396        47020        1.79
# Banner           inMobi 2018-10-04  Zedge      89        25214       75.72
# Banner           inMobi 2018-10-04  Zedge      88        13209        2.02
# Banner           inMobi 2018-10-04  Zedge      27        17156        3.08
# Banner           inMobi 2018-10-04  Zedge     248        21218        5.57
# Banner           inMobi 2018-10-04  Zedge      25         8241       16.88
# Banner           inMobi 2018-10-04  Zedge     887        92315        3.78
# Banner           inMobi 2018-10-04  Zedge      99        28399        2.43
# Banner           inMobi 2018-10-04  Zedge     240        53772        7.17
# Banner           inMobi 2018-10-04  Zedge      32        20254       36.91
# Banner           inMobi 2018-10-04  Zedge      63        59512      168.92
# Banner           inMobi 2018-10-04  Zedge      75         9151        2.33
# Banner           inMobi 2018-10-04  Zedge     608       128831       18.77
# Banner           inMobi 2018-10-04  Zedge      45        14663        5.54
# Banner           inMobi 2018-10-04  Zedge      16         5698        1.88
# Banner           inMobi 2018-10-04  Zedge     138        27370        3.69
# Banner           inMobi 2018-10-04  Zedge       7         4244        2.26
# Banner           inMobi 2018-10-04  Zedge      83        17848        4.31
# Banner           inMobi 2018-10-04  Zedge      20        12394        5.13
# Banner           inMobi 2018-10-04  Zedge     169        20225        3.28
# Banner           inMobi 2018-10-04  Zedge      17         5374        1.04
# Banner           inMobi 2018-10-04  Zedge      71        38316        2.10
# Banner           inMobi 2018-10-04  Zedge     385        26453        8.80
# Banner           inMobi 2018-10-04  Zedge     168        30830        3.81
# Banner           inMobi 2018-10-04  Zedge      44        19928        1.69
# ...                 ...        ...    ...     ...          ...         ...
# Banner            Other 2017-10-08  Zedge     623       125105       85.00
# Banner            Other 2017-10-08  Zedge    1742        15855        7.40
# Banner            Other 2017-10-08  Zedge      16         2856        1.18
# Banner            Other 2017-10-08  Zedge      93        17229        8.18
# Banner            Other 2017-10-08  Zedge      91        23318       14.31
# Banner            Other 2017-10-08  Zedge       7         3527        1.59
# Banner            Other 2017-10-08  Zedge      10         3176        1.40
# Banner            Other 2017-10-08  Zedge      76         7191        3.26
# Banner            Other 2017-10-08  Zedge      44         7552        3.45
# Banner            Other 2017-10-08  Zedge      23         4115        2.01
# Banner            Other 2017-10-08  Zedge     306        63880       39.76
# Banner            Other 2017-10-08  Zedge    1467       304569      183.65
# Interstitial      Other 2017-10-08  Zedge     524         1255       20.07
# Interstitial      Other 2017-10-08  Zedge     177          413        6.35
# Interstitial      Ogury 2017-10-08  Zedge       0        13607      163.28
# Interstitial      Ogury 2017-10-08  Zedge       0        16322      195.86
# Interstitial      Ogury 2017-10-08  Zedge       0          148        1.78
# Interstitial      Ogury 2017-10-08  Zedge       0        10584      127.01
# Interstitial      Ogury 2017-10-08  Zedge       0         1448       17.38
# Interstitial      Ogury 2017-10-08  Zedge       0         1438       17.26
# Interstitial      Ogury 2017-10-08  Zedge       0         1796       21.55
# Interstitial      Ogury 2017-10-08  Zedge       0         8706      104.47
# Interstitial      Ogury 2017-10-08  Zedge       0         1519       18.23
# Interstitial      Ogury 2017-10-08  Zedge       0         3833       46.00
# Interstitial      Ogury 2017-10-08  Zedge       0        43700      524.40
# Interstitial      Ogury 2017-10-08  Zedge       0         3177       38.12
# Interstitial      Ogury 2017-10-08  Zedge       0         1140       13.68
# Interstitial      Ogury 2017-10-08  Zedge       0        66897      802.76
# Banner            Other 2017-10-08  Zedge      18       700539      649.26
# MREC              Admob 2017-10-08  Zedge       1           14        2.11
#
#              tier country  year  month     partner
# ad_name
# MREC            1      GB  2018     10       Admob
# Banner          3      IN  2018     10      Adview
# Banner          3      ID  2018     10      Adview
# Banner          1      US  2018     10      Adview
# Banner          1      US  2018     10  Conversant
# Banner          3      AR  2018     10      inMobi
# Banner          1      AU  2018     10      inMobi
# Banner          2      AT  2018     10      inMobi
# Banner          2      BE  2018     10      inMobi
# Banner          3      BR  2018     10      inMobi
# Banner          1      CA  2018     10      inMobi
# Banner          3      CO  2018     10      inMobi
# Banner          3      EG  2018     10      inMobi
# Banner          3      FI  2018     10      inMobi
# Banner          2      FR  2018     10      inMobi
# Banner          2      DE  2018     10      inMobi
# Banner          3      GR  2018     10      inMobi
# Banner          3      IN  2018     10      inMobi
# Banner          3      ID  2018     10      inMobi
# Banner          2      IE  2018     10      inMobi
# Banner          3      IT  2018     10      inMobi
# Banner          3      JO  2018     10      inMobi
# Banner          3      MY  2018     10      inMobi
# Banner          3      MX  2018     10      inMobi
# Banner          2      NL  2018     10      inMobi
# Banner          2      NO  2018     10      inMobi
# Banner          3      PK  2018     10      inMobi
# Banner          3      PL  2018     10      inMobi
# Banner          3      OU  2018     10      inMobi
# Banner          3      RO  2018     10      inMobi
# ...           ...     ...   ...    ...         ...
# Banner          2      DE  2017     10      Nexage
# Banner          3      GR  2017     10      Nexage
# Banner          3      ID  2017     10      Nexage
# Banner          3      IT  2017     10      Nexage
# Banner          3      MX  2017     10      Nexage
# Banner          2      NL  2017     10      Nexage
# Banner          2      NO  2017     10      Nexage
# Banner          3      RU  2017     10      Nexage
# Banner          2      ES  2017     10      Nexage
# Banner          2      SE  2017     10      Nexage
# Banner          1      GB  2017     10      Nexage
# Banner          1      US  2017     10      Nexage
# Interstitial    1      CA  2017     10      Nexage
# Interstitial    1      US  2017     10      Nexage
# Interstitial    2      DE  2017     10       Ogury
# Interstitial    2      FR  2017     10       Ogury
# Interstitial    3      CN  2017     10       Ogury
# Interstitial    3      IT  2017     10       Ogury
# Interstitial    3      IL  2017     10       Ogury
# Interstitial    2      NL  2017     10       Ogury
# Interstitial    3      ZA  2017     10       Ogury
# Interstitial    2      ES  2017     10       Ogury
# Interstitial    2      SG  2017     10       Ogury
# Interstitial    3      PL  2017     10       Ogury
# Interstitial    1      GB  2017     10       Ogury
# Interstitial    3      AE  2017     10       Ogury
# Interstitial    3      RU  2017     10       Ogury
# Interstitial    1      US  2017     10       Ogury
# Banner          1      US  2017     10       OpenX
# MREC            2      NO  2017     10       Admob
#
# [170171 rows x 11 columns]

# %%
q4_revenue_data.reset_index(inplace=True)

# %%
q4_agg = q4_revenue_data.groupby(['year', 'tier', 'ad_name', 'connection']).sum()

q4_agg

q4_agg.reset_index(inplace=True)

q4_agg
# Out:
#      year tier         ad_name   connection    clicks  impressions  \
# 0    2017    1          Banner        Admob    266919    102584644
# 1    2017    1          Banner     Facebook    105592     42920459
# 2    2017    1          Banner  Marketplace    908200    269339768
# 3    2017    1          Banner        Other    170398    113699736
# 4    2017    1          Banner       inMobi   1136294    113443348
# 5    2017    1    Interstitial        Admob    194358      8997470
# 6    2017    1    Interstitial     Facebook     41891      4439526
# 7    2017    1    Interstitial  Marketplace   2576292     30991883
# 8    2017    1    Interstitial        Ogury         0     27030222
# 9    2017    1    Interstitial        Other    262020       299319
# 10   2017    1    Interstitial       inMobi      1285        20755
# 11   2017    1            MREC        Admob      5604       372684
# 12   2017    1            MREC  Marketplace      6420       571388
# 13   2017    1          Native        Admob    700538     84057409
# 14   2017    1          Native     Facebook    894277    133186283
# 15   2017    1          Native  Marketplace   3594053    227339726
# 16   2017    1          Native       inMobi     12990      1319745
# 17   2017    1  Rewarded Video        Admob        49         1757
# 18   2017    2          Banner        Admob    251280    108800077
# 19   2017    2          Banner     Facebook     50638     14061880
# 20   2017    2          Banner  Marketplace    287488     58936484
# 21   2017    2          Banner        Other     62903     18509568
# 22   2017    2          Banner       inMobi     72771      6855497
# 23   2017    2    Interstitial        Admob     95867      9342560
# 24   2017    2    Interstitial     Facebook     29378      3848574
# 25   2017    2    Interstitial  Marketplace    910557     11241808
# 26   2017    2    Interstitial        Ogury         0      5686640
# 27   2017    2    Interstitial        Other      1636         4519
# 28   2017    2    Interstitial       inMobi       939         5338
# 29   2017    2            MREC        Admob       254        10812
# ..    ...  ...             ...          ...       ...          ...
# 86   2018    2            MREC       inMobi        85        10213
# 87   2018    2          Native        Admob    481667     96689012
# 88   2018    2          Native     Facebook     39914      9979809
# 89   2018    2          Native  Marketplace    287582     26813697
# 90   2018    2  Rewarded Video        Admob      2518       214102
# 91   2018    2  Rewarded Video     Facebook       283        13027
# 92   2018    2  Rewarded Video  Marketplace       861        13820
# 93   2018    2  Rewarded Video        Other         0        42748
# 94   2018    3          Banner        Admob    911349    401736822
# 95   2018    3          Banner     Facebook    128066     27017997
# 96   2018    3          Banner  Marketplace   1653911    283682085
# 97   2018    3          Banner        Other  90635429     19349453
# 98   2018    3          Banner       inMobi    425425     61294176
# 99   2018    3    Interstitial        Admob    347539     40822090
# 100  2018    3    Interstitial     Facebook    199101     19869821
# 101  2018    3    Interstitial  Marketplace  11158388     89320882
# 102  2018    3    Interstitial        Ogury         0       936174
# 103  2018    3    Interstitial        Other  26305773       715604
# 104  2018    3    Interstitial       inMobi    183305      5672132
# 105  2018    3            MREC        Admob     32715      6933769
# 106  2018    3            MREC  Marketplace    105679      3659129
# 107  2018    3            MREC       inMobi      4077       216201
# 108  2018    3          Native        Admob   1291092    373781034
# 109  2018    3          Native     Facebook    620476    135873413
# 110  2018    3          Native  Marketplace   2440424    275976847
# 111  2018    3          Native        Other    706053     42089009
# 112  2018    3  Rewarded Video        Admob     23790      2153539
# 113  2018    3  Rewarded Video     Facebook      2171       108931
# 114  2018    3  Rewarded Video  Marketplace      4059        24513
# 115  2018    3  Rewarded Video        Other         0       465818
#
#      ad_revenue   month
# 0      66711.86    8096
# 1      10911.87    6284
# 2     232392.86    7524
# 3      93233.73   12688
# 4     111409.65    6164
# 5      74908.48    7638
# 6      18707.74    9154
# 7     339342.31   10969
# 8     324362.48    2468
# 9       5561.97     553
# 10       119.73     277
# 11      1126.48    4300
# 12      1289.36    1336
# 13    138335.31   17194
# 14    110229.86   11964
# 15    317448.14   14129
# 16      1221.62    1429
# 17        61.38     252
# 18     24666.06   26469
# 19      3998.43    9177
# 20     24185.58   18920
# 21     11470.65   13113
# 22      1599.25    4583
# 23     24993.22   21361
# 24      6319.68   10950
# 25     40619.86   25263
# 26     68239.69    7164
# 27       105.05     152
# 28        14.89     110
# 29        82.99     602
# ..          ...     ...
# 86        14.93     106
# 87     64240.22   59553
# 88      2317.15    9818
# 89     18683.39   25743
# 90      2325.20    5790
# 91       183.93     408
# 92       116.03     606
# 93       467.39    1800
# 94     59347.34   73494
# 95      1007.25    5944
# 96     48202.54   31367
# 97      5999.90    6475
# 98     12073.54   21225
# 99     49649.88   59912
# 100    13403.28   37513
# 101   152611.82   43233
# 102    11234.11    2594
# 103      860.94    2301
# 104     4887.23    9953
# 105     2800.08    9370
# 106     1791.65    4548
# 107       48.79     288
# 108    62193.02  131671
# 109    10991.09   38187
# 110    55738.04   73673
# 111    48546.99    3036
# 112     6628.66   15544
# 113      236.97    1445
# 114       74.65     451
# 115      756.99    3690
#
# [116 rows x 8 columns]

# %%
# grab sums of each ad_name by Year and Tier
q4_sums = q4_agg.groupby(['year','tier', 'ad_name']).sum()
q4_sums.reset_index(inplace=True)

q4_merge = pd.merge(q4_agg, q4_sums, how='inner', on = ['year', 'tier','ad_name'])

q4_merge

q4_merge['sow'] = q4_merge.ad_revenue_x / q4_merge.ad_revenue_y

q4_sow = q4_merge[['year', 'tier', 'ad_name', 'ad_revenue_x','ad_revenue_y','sow','connection']]

q4_sow
q4_sow2018 = q4_sow[q4_sow['year'] == 2018]

# %%
# export to excel to use Tableau for the percentage chart
q4_sow.to_csv('q4_sow_for_tableau.csv')
